# %% [markdown]
# # Python Basic(Assignment 4)

# %% [markdown]
# ## 1. What exactly is [ ]?
#
# * This is [ ] empty list value, list that contains no items.

# %% [markdown]
# ## 2. In a list of values stored in a variable called spam, how would you assign the value     &#39;hello&#39; as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
#
# *  The third value in a list is at index 2 because the first index is 0.

# %%
spam = [2,4,6,8,10]
spam[2] = 'Hello'

print(spam)
# Out:
# [2, 4, 'Hello', 8, 10]

# %% [markdown]
# ## 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %%
spam = ['a','b','c','d']
int(int('3' * 2) / 11)
# Out:
# 3

# %% [markdown]
# ## 4. What is the value of spam[-1]?

# %%
# Negative indexes count from the end
spam = [2,4,6,8,10]
spam[-1]
# Out:
# 10

# %% [markdown]
# ## 5. What is the value of spam[:2]?

# %%
spam[:2]
# Out:
# [2, 4]

# %% [markdown]
# ## 6. What is the value of bacon.index(&#39;cat&#39;)?

# %%
# The third value in a list is at index 2 because the first index is 0.
bacon = [3.14,'cat',11,'cat',True]
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# ## 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon = [3.14,'cat',11,'cat',True]
bacon.append(99)

print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ## 8. How does bacon.remove(&#39;cat&#39;) change the look of the list meaning in bacon?

# %%
bacon = [3.14,'cat',11,'cat',True]
bacon.remove('cat')

print(bacon)
# Out:
# [3.14, 11, 'cat', True]

# %% [markdown]
# ## 9. What are the list concatenation and list replication operators?

# %%
# operator for list concatenation is +, while the operator for replication is *.
a = 'The Best Institute is '
b = 'ineuron'

# concatenation
concate = a + b

print(concate)
# Out:
# The Best Institute is ineuron

# %%
# Replication
a = 3
b = '  ineuron'

repli = a * b

print(repli)
# Out:
#   ineuron  ineuron  ineuron

# %% [markdown]
# ## 10. What is difference between the list methods append() and insert()?
#
# * The append() will add values only to the end of a list, insert() can add them anywhere in the list

# %%
spam = [2,4,6,8,10]
spam2 = [4,6,8,10,12]

for i in spam:
    spam2.append(i)

print('spam2',spam2)
# Out:
# spam2 [4, 6, 8, 10, 12, 2, 4, 6, 8, 10]

# %%
spam = [4, 6, 8, 10, 12, 2, 4, 6, 8, 10]

spam.insert(2,15)

print('spam',spam)
# Out:
# spam [4, 6, 15, 8, 10, 12, 2, 4, 6, 8, 10]

# %% [markdown]
# ## 11. What are the two methods for removing items from a list?
#
# * The del statement and the remove() list method are two ways to remove values from a list

# %%
#Method -1
spam = [4, 6, 8, 10, 12, 2, 4, 6, 8, 10]

spam.remove(12)
print('spam',spam)
# Out:
# spam [4, 6, 8, 10, 2, 4, 6, 8, 10]

# %%
#Method -2(random remove)
spam = [4, 6, 8, 10, 12, 2, 4, 6, 8, 10]

spam.pop()
print('spam',spam)
# Out:
# spam [4, 6, 8, 10, 12, 2, 4, 6, 8]

# %% [markdown]
# ## 12. Describe how list values and string values are identical.
#
# * Both lists and strings can be passed to len(), have to indexes and slices, be used in for loops, be concatenated or replicated.

# %% [markdown]
# ## 13. What&#39;s the difference between tuples and lists?
#
# * Lists are mutable; they can added, removed, or changed the values
# + lists use the square brackets [ and ].
#
#
# * Tuples are immutable; they cannot be changed at all.
# + tuples are written using parentheses, ( and ).

# %% [markdown]
# ## 14. How do you type a tuple value that only contains the integer 42?
#
# * Trailing comma is mandatory.

# %%
spam = (1,2,3,4,5,6)

# %% [markdown]
# ## 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %%
Tuple = (123, 'Cricket', 'Fifa', 'Basketball');
List = list(Tuple)
print("List elements : ", List)
# Out:
# List elements :  [123, 'Cricket', 'Fifa', 'Basketball']

# %% [markdown]
# ## 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# contain references to list values.

# %% [markdown]
# ## 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# * The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.

# %%
#Using copy.copy()

old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.copy(old_list)

print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#Using deep.copy()

old_list = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
new_list = copy.deepcopy(old_list)

print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
# New list: [[1, 1, 1], [2, 2, 2], [3, 3, 3]]

# %% [markdown]
# ## Thankyou
