# %% [markdown]
# # Python Basic(Assignment 6)

# %% [markdown]
# ## 1. What are escape characters, and how do you use them?
#
# * Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code.

# %%
txt = "We are Valorant\"The Gamer\" from the Asia."
print(txt)
# Out:
# We are Valorant"The Gamer" from the Asia.

# %% [markdown]
# ## 2. What do the escape characters n and t stand for?
#
# * \n is a newline
# * \t is a tab

# %%
# New Line(\n)
my_str='''Hello all!! \nI am Pythoner \nWelcome to the ineuron'''
print(my_str)
# Out:
# Hello all!!
# I am Pythoner
# Welcome to the ineuron

# %%
# New Tab(\t)
my_str='''Hello all!! \tI am Pythoner \tWelcome to the ineuron'''
print(my_str)
# Out:
# Hello all!! 	I am Pythoner 	Welcome to the ineuron

# %% [markdown]
# ## 3. What is the way to include backslash characters in a string?
#
# * The \ \ escape character will represent a backslash character.

# %%
txt = "We are Valorant\"The Gamer\" from the Asia."
print(txt)
# Out:
# We are Valorant"The Gamer" from the Asia.

# %% [markdown]
# ## 4. The string &quot;Howl&#39;s Moving Castle&quot; is a correct value. Why isn&#39;t the single quote character in the word Howl&#39;s not escaped a problem?
#
# * The single quote in Howl's is fine because you’ve used double quotes to mark the beginning and end of the string.

# %%
my_str = "The string Howl's Moving Castle"
print(my_str)
# Out:
# The string Howl's Moving Castle

# %% [markdown]
# ## 5. How do you write a string of newlines if you don&#39;t want to use the n character?

# %%
my_str= """"Hello all!! 
I am Pythoner  
Welcome to the ineuron"""
print(my_str)
# Out:
# "Hello all!!
# I am Pythoner
# Welcome to the ineuron

# %% [markdown]
# ## 6. What are the values of the given expressions?
#
# &#39;Hello, world!&#39;[1]
#
# &#39;Hello, world!&#39;[0:5]
#
# &#39;Hello, world!&#39;[:5]
#
# &#39;Hello, world!&#39;[3:]

# %%
my_str = 'Hello, world!'
'Hello, world!'[1]
# Out:
# 'e'

# %%
my_str = 'Hello, world!'
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
my_str = 'Hello, world!'
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
my_str = 'Hello, world!'
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %% [markdown]
# ## 7. What are the values of the following expressions?
#
# &#39;Hello&#39;.upper()
#
# &#39;Hello&#39;.upper().isupper()
#
# &#39;Hello&#39;.upper().lower()

# %%
my_str = 'Hello, world!'
'Hello'.upper()
# Out:
# 'HELLO'

# %%
my_str = 'Hello, world!'
'Hello'.upper().isupper()
# Out:
# True

# %%
my_str = 'Hello, world!'
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ## 8. What are the values of the following expressions?
#
# &#39;Remember, remember, the fifth of July.&#39;.split()
#
# &#39;-&#39;.join(&#39;There can only one.&#39;.split())

# %%
'Remember, remember, the fifth of July.'.split()

'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ## 9. What are the methods for right-justifying, left-justifying, and centering a string?
#
# * The rjust(), ljust(), and center() string methods, respectively

# %%
txt = "ineuron"

x = txt.rjust(20)

print(x, "is best institute.")
# Out:
#              ineuron is best institute.

# %%
txt = "ineuron"

x = txt.ljust(10)

print(x, "is best institute.")
# Out:
# ineuron    is best institute.

# %%
txt = "ineuron"

x = txt.center(10)

print(x, "is best institute.")
# Out:
#  ineuron   is best institute.

# %% [markdown]
# ## 10. What is the best way to remove whitespace characters from the start or end?
#
# * The lstrip() and rstrip() methods remove whitespace from the left and right ends of a string, respectively.

# %%
txt = "ineuron"

x = txt.lstrip()

print(x, "is best institute.")
# Out:
# ineuron is best institute.

# %%
txt = "ineuron"

x = txt.rstrip()

print(x, "is best institute.")
# Out:
# ineuron is best institute.

# %% [markdown]
# #                                        Thankyou
